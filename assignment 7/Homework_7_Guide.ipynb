# %% [markdown]
# ### Homework 7 Homework Guide
# <br>
# In this guide, we will run through using kmean to cluster data from the soccer database. We will need the following libraries.

# %%
import sqlite3
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %% [markdown]
# First, let's connect to the database as we've done in previous guides below.

# %%
conn = #Connection Code Here

# %% [markdown]
# From the database, grab `gk_reflexes` and `gk_handling` from the `Player_Attributes` table.

# %%
player_attr_df = # Data Grab Here
player_attr_df.fillna(11, inplace=True)

# %% [markdown]
# Let's run the `KMeans()` function, using `n_clusers = 5` as our starting cluster count below.

# %%
km = _(n_clusters = 'Your Value Here', init = 'random', n_init = 10, max_iter= 300, tol=1e-04, random_state=1)
ykm = km.fit_predict(player_attr_df)

# %% [markdown]
# Plot the results using the `scatter()` function, passing `player_attr_df.gk_handling` and `player_attr_df.gk_reflexes` as the first two arguments.

# %%
plt._(_, _, marker='o', s = 50, cmap='viridis')
centers = km.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c ='black', s = 200)

plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# Above we can see the 5 centroids from the clustering. It looks like we can probably choose a better cluster number. Let's run the elbow method below to find a better cluster count. Once done, plot the distance in the `plt.plot()` so we can see which value to use.

# %%
dist= []
for i in range(1, 11):
    km = KMeans(n_clusters = i, init = 'k-means++', n_init = 10, max_iter= 300, random_state=0)
    km.fit(player_attr_df)
    dist.append(km.inertia_)

# Pass dist where the parameter underscore is below
plt._(range(1,11), _, marker = 'o')
plt.tight_layout()
plt.show()

# %% [markdown]
# Looks like we should use 2! In the cell below, run `KMeans()` again, same as previously in this guide, and use 2 clusters.

# %%
km = # Run KMeans again here
ykm = # Fit Predict Here
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d77a3005f96a> in <module>
#       1 km = KMeans(n_clusters = 2, init = 'random', n_init = 10, max_iter= 300, tol=1e-04, random_state=1)
#       2 ykm = km.fit_predict(player_attr_df)
# ----> 3 plt.scatter(x[:,0], x[:,1], marker='o', s = 50, cmap='viridis')
#       4 centers = km.cluster_centers_
#       5 plt.scatter(centers[:,0], centers[:,1], c ='black', s = 200)
#
# NameError: name 'x' is not defined

# %% [markdown]
# Lastly, plot your results.

# %%
# Plot as we did before

# %% [markdown]
# And that's it! Make sure to save the guide with your output and graphs, and submit. Make sure your sumbitted file can be opened with Jupyter Notebook.
